# %%
from ultralytics import YOLO

# # Load a model
# model = YOLO("best.pt")

# %%
from ultralytics import YOLO
from ultralytics import settings

# %%
# View all settings
print(settings, "\n")

# View datasets_dir setting
print("before: " + settings["datasets_dir"])

# Update the datasets_dir setting
settings.update({"datasets_dir": "/Users/seunghyunlee/Desktop/aps360_project/dataset"})

# View datasets_dir setting after updating
print("after: " + settings["datasets_dir"])
# Out:
# JSONDict("/Users/catherinexiong/Library/Application Support/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/Users/seunghyunlee/Desktop/aps360_project/dataset",
#   "weights_dir": "weights",
#   "runs_dir": "runs",
#   "uuid": "c3d09ea4a385f2202b7db198daa2ae39d51a40a88ae832686408e79a0ea4931b",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": true,
#   "wandb": false,
#   "vscode_msg": true
# }
#
# before: /Users/seunghyunlee/Desktop/aps360_project/dataset
# after: /Users/seunghyunlee/Desktop/aps360_project/dataset

# %%
# !yolo settings dataset_dir='/Users/seunghyunlee/Desktop/aps360_project/dataset'
# Out:
# WARNING ⚠️ settings error: ''dataset_dir' is not a valid YOLO argument. Similar arguments are i.e. ['datasets_dir=/Users/seunghyunlee/Desktop/aps360_project/dataset'].
#
#     Arguments received: ['yolo', 'settings', 'dataset_dir=/Users/seunghyunlee/Desktop/aps360_project/dataset']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of frozenset({'classify', 'pose', 'segment', 'detect', 'obb'})
#                 MODE (required) is one of frozenset({'val', 'track', 'benchmark', 'train', 'predict', 'export'})
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
#                     See all ARGS at https://docs.ultralytics.com/usage/cfg or with 'yolo cfg'
#
#     1. Train a detection model for 10 epochs with an initial learning_rate of 0.01
#         yolo train data=coco8.yaml model=yolo11n.pt epochs=10 lr0=0.01
#
# ...

# %%
# import os

# # Now you can use the original path
# model.train(data="/Users/seunghyunlee/Desktop/aps360_project/dataset/eye_v5/data.yaml", epochs=10, imgsz=480, batch=64, device="mps")

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
import os
import cv2
from ultralytics import YOLO

# %%
model = YOLO("yolo5v.pt")

# %%
import cv2
from ultralytics import YOLO

cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    # Resize frame to match the training image size (160x96)
    resized_frame = cv2.resize(frame, (160, 96))
    
    # Make detections with lower confidence threshold
    results = model(resized_frame, conf=0.25)  # Lower confidence threshold
    
    # Access the first result
    result = results[0]
    
    # Check if there are any detections
    if len(result.boxes) > 0:
        # Draw the detections on a copy of the original frame
        # We'll scale the bounding boxes back to the original frame size
        rendered_frame = frame.copy()
        h, w, _ = frame.shape
        scale_x = w / 160
        scale_y = h / 96
        
        for box in result.boxes:
            # Get box coordinates, class and confidence
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            
            # Scale coordinates to original frame size
            x1, x2 = int(x1 * scale_x), int(x2 * scale_x)
            y1, y2 = int(y1 * scale_y), int(y2 * scale_y)
            
            cls = int(box.cls[0])
            conf = float(box.conf[0])
            class_name = result.names[cls]
            
            # Draw rectangle and label
            color = (0, 255, 0) if class_name == 'opened' else (0, 0, 255)
            cv2.rectangle(rendered_frame, (x1, y1), (x2, y2), color, 2)
            label = f"{class_name} {conf:.2f}"
            cv2.putText(rendered_frame, label, (x1, y1 - 10), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)
    else:
        rendered_frame = frame  # If no boxes, show the original frame
    
    # Display the image
    cv2.imshow('YOLO', rendered_frame)
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 2025-03-20 12:21:10.328 python[23511:2929130] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# 0: 384x640 1 closed, 90.7ms
# Speed: 6.2ms preprocess, 90.7ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 opened, 268.7ms
# Speed: 2.9ms preprocess, 268.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 opened, 104.6ms
# Speed: 4.9ms preprocess, 104.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 opened, 137.5ms
# Speed: 2.7ms preprocess, 137.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 opened, 72.3ms
# Speed: 2.4ms preprocess, 72.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 opened, 84.6ms
# ...
