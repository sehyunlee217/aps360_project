# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install jupyterlab ultralytics

from ultralytics import YOLO

model = YOLO('yolov5n.pt')
model.train(data='/content/drive/MyDrive/dataset/data.yaml', epochs=100, imgsz=640)
# Out:
# ...
# PRO TIP 💡 Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Ultralytics 8.3.83 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
print(os.listdir('runs/detect/train2/weights/'))
# Out:
# ['best.pt', 'last.pt']

# %%
import shutil

# Create a folder to store your model
backup_dir = "my_models"
shutil.os.makedirs(backup_dir, exist_ok=True)

# Copy the best model to the backup folder
shutil.copy("runs/detect/train2/weights/best.pt", f"{backup_dir}/yolo_best.pt")
# Out:
# 'my_models/yolo_best.pt'

# %%
shutil.copy("runs/detect/train2/weights/best.pt", "/content/drive/MyDrive/yolo_best.pt")
# Out:
# '/content/drive/MyDrive/yolo_best.pt'

# %%
import cv2

# Open webcam (0 = default camera, change to 1 for external webcam)
cap = cv2.VideoCapture(1)

while cap.isOpened():
    ret, frame = cap.read()  # Read a frame from the webcam
    if not ret:
        break

    # Run YOLO model on the frame
    results = model(frame)

    # Visualize results on the frame
    annotated_frame = results[0].plot()

    # Display the frame
    cv2.imshow("YOLO Real-Time Detection", annotated_frame)

    # Press 'q' to exit the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 1. Install and Import Dependencies

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# # 2. Load Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2025-3-4 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %% [markdown]
# # 3. Make Detections with Images

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
import requests
from PIL import Image
# Specify the image URL
img_url = 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/e4/Cars_in_traffic_in_Auckland%2C_New_Zealand_-_copyright-free_photo_released_to_public_domain.jpg/800px-Cars_in_traffic_in_Auckland%2C_New_Zealand_-_copyright-free_photo_released_to_public_domain.jpg'

# Download the image from the URL, including the custom headers
headers = {
    'User-Agent': 'MyBot/1.0 (Your Email or Website; https://yourwebsite.com)'
}
response = requests.get(img_url, stream=True, headers=headers)
response.raise_for_status()  # Raise an exception for bad responses (like 404)

# Open the image using Pillow
img = Image.open(response.raw)

# Perform inference
results = model(img)

# Print results
results.print()

# Display the image with detections
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 533x800 2 persons, 28 cars, 5 trucks
# Speed: 64.4ms pre-process, 51.8ms inference, 459.6ms NMS per image at shape (1, 3, 448, 640)

# %%
results.render()
# Out:
# [array([[[251, 216, 174],
#          [254, 220, 175],
#          [246, 213, 168],
#          ...,
#          [127, 149, 146],
#          [ 67,  79,  55],
#          [ 64,  70,  34]],
#
#         [[235, 201, 156],
#          [233, 200, 155],
#          [221, 189, 142],
#          ...,
#          [120, 142, 140],
#          [ 82,  92,  67],
#          [ 46,  52,  16]],
#
#         [[252, 220, 171],
#          [245, 213, 164],
#          [212, 180, 131],
#          ...,
#          [135, 155, 154],
#          [ 66,  74,  50],
#          [ 58,  62,  25]],
#
#         ...,
#
#         [[ 61,  69,  80],
#          [ 64,  72,  83],
#          [ 61,  69,  80],
#          ...,
#          [ 47,  52,  56],
#          [ 48,  53,  57],
#          [ 49,  54,  58]],
#
#         [[ 56,  64,  75],
#          [ 72,  80,  91],
#          [ 70,  78,  89],
#          ...,
#          [ 48,  53,  57],
#          [ 48,  53,  57],
#          [ 50,  55,  59]],
#
#         [[ 64,  72,  83],
# ...

# %% [markdown]
# # 4. Real Time Detections

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()

    # Make detections
    results = model(frame)

    cv2.imshow('YOLO', np.squeeze(results.render()))

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 5. Train from scratch

# %%
import uuid   # Unique identifier
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images') #/data/images
labels = ['awake', 'drowsy']
number_imgs = 5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)

    # Loop through image range
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))

        # Webcam feed
        ret, frame = cap.read()

        # Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')

        # Writes out image to file
        cv2.imwrite(imgname, frame)

        # Render to the screen
        cv2.imshow('Image Collection', frame)

        # 2 second delay between captures
        time.sleep(2)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-26-cbf4c59f9678> in <cell line: 0>()
#      16
#      17         # Writes out image to file
# ---> 18         cv2.imwrite(imgname, frame)
#      19
#      20         # Render to the screen
#
# error: OpenCV(4.11.0) /io/opencv/modules/imgcodecs/src/loadsave.cpp:929: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'

# %%
print(os.path.join(IMAGES_PATH, labels[0]+'.'+str(uuid.uuid1())+'.jpg'))
# Out:
# data/images/awake.52dd57ba-f94b-11ef-bae9-0242ac1c000c.jpg

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# ...
# data/images/awake.539ad4b6-f94b-11ef-bae9-0242ac1c000c.jpg
# ...
# data/images/awake.539ad678-f94b-11ef-bae9-0242ac1c000c.jpg
# ...
# data/images/awake.539ad754-f94b-11ef-bae9-0242ac1c000c.jpg
# ...
# data/images/awake.539ad812-f94b-11ef-bae9-0242ac1c000c.jpg
# ...
# data/images/awake.539ad8c6-f94b-11ef-bae9-0242ac1c000c.jpg
# ...
# data/images/drowsy.539ad9a2-f94b-11ef-bae9-0242ac1c000c.jpg
# ...
# data/images/drowsy.539ada6a-f94b-11ef-bae9-0242ac1c000c.jpg
# ...
# data/images/drowsy.539adb1e-f94b-11ef-bae9-0242ac1c000c.jpg
# ...
# data/images/drowsy.539adbc8-f94b-11ef-bae9-0242ac1c000c.jpg
# ...
# data/images/drowsy.539adc7c-f94b-11ef-bae9-0242ac1c000c.jpg

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# Cloning into 'labelImg'...
# remote: Enumerating objects: 2097, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 2097 (delta 0), reused 0 (delta 0), pack-reused 2093 (from 2)
# Receiving objects: 100% (2097/2097), 237.14 MiB | 19.13 MiB/s, done.
# Resolving deltas: 100% (1245/1245), done.

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 74.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 MB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.4/276.4 kB 23.2 MB/s eta 0:00:00
# ...

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt --workers 2
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-03-04 22:53:16.666729: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741128796.913004    5342 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741128797.003813    5342 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# ...

# %% [markdown]
# # 6. Load Custom Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp15/weights/last.pt', force_reload=True)

# %%
img = os.path.join('data', 'images', 'awake.c9a24d48-e1f6-11eb-bbef-5cf3709bbcc6.jpg')

# %%
results = model(img)

# %%
results.print()

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()

    # Make detections
    results = model(frame)

    cv2.imshow('YOLO', np.squeeze(results.render()))

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
