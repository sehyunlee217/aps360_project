# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)

# %%
from ultralytics import settings

# %%
# !yolo settings dataset_dir='yolov8_proj_data/'

# %%
# View all settings
print(settings, "\n")

# View datasets_dir setting
print("before: " + settings["datasets_dir"])

# Update the datasets_dir setting
settings.update({"datasets_dir": "/Users/seunghyunlee/Desktop/aps360_project/yolo_480p_data"})

# View datasets_dir setting after updating
print("after: " + settings["datasets_dir"])
# Out:
# JSONDict("/Users/seunghyunlee/Library/Application Support/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/Users/seunghyunlee/Desktop/aps360_project/yolo_480p_data",
#   "weights_dir": "weights",
#   "runs_dir": "runs",
#   "uuid": "572e907956ed2499faade1f92bc5033f548a7fb0210d9ccaee9b54ebf0286c75",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": true,
#   "wandb": false,
#   "vscode_msg": true
# }
#
# before: /Users/seunghyunlee/Desktop/aps360_project/yolo_480p_data
# after: /Users/seunghyunlee/Desktop/aps360_project/yolo_480p_data

# %%
# !pwd
# Out:
# /Users/seunghyunlee/Desktop/aps360_project

# %%
model.train(data="yolo_480p_data/data.yaml", epochs=10, imgsz=480, batch=64, device="mps")
# Out:
# New https://pypi.org/project/ultralytics/8.3.83 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.79 🚀 Python-3.12.4 torch-2.3.1 MPS (Apple M1 Pro)
# ...

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
import os
import cv2
from ultralytics import YOLO

# %%
model = YOLO("yolo_zach.pt")

# %%
img = os.path.join('custom_data', 'images', 'closed_check.jpg')
custom_data_path = os.path.join('custom_data', 'images')

# %%
for img in

# %%
results = model(img)
# Out:
# image 1/1 /Users/seunghyunlee/Desktop/aps360_project/custom_data/images/closed_check.jpg: 384x640 1 closed, 59.2ms
# Speed: 5.1ms preprocess, 59.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)

# %%
results[0].show()

# %%
import cv2
from ultralytics import YOLO

# Load the model - ensure you're using the best weights from your training
model = YOLO("yolo_zach.pt")  # Use your trained model path

cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    # Resize frame to match the training image size (160x96)
    resized_frame = cv2.resize(frame, (160, 96))
    
    # Make detections with lower confidence threshold
    results = model(resized_frame, conf=0.25)  # Lower confidence threshold
    
    # Access the first result
    result = results[0]
    
    # Check if there are any detections
    if len(result.boxes) > 0:
        # Draw the detections on a copy of the original frame
        # We'll scale the bounding boxes back to the original frame size
        rendered_frame = frame.copy()
        h, w, _ = frame.shape
        scale_x = w / 160
        scale_y = h / 96
        
        for box in result.boxes:
            # Get box coordinates, class and confidence
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            
            # Scale coordinates to original frame size
            x1, x2 = int(x1 * scale_x), int(x2 * scale_x)
            y1, y2 = int(y1 * scale_y), int(y2 * scale_y)
            
            cls = int(box.cls[0])
            conf = float(box.conf[0])
            class_name = result.names[cls]
            
            # Draw rectangle and label
            color = (0, 255, 0) if class_name == 'opened' else (0, 0, 255)
            cv2.rectangle(rendered_frame, (x1, y1), (x2, y2), color, 2)
            label = f"{class_name} {conf:.2f}"
            cv2.putText(rendered_frame, label, (x1, y1 - 10), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)
    else:
        rendered_frame = frame  # If no boxes, show the original frame
    
    # Display the image
    cv2.imshow('YOLO', rendered_frame)
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 2025-03-04 22:12:37.452 python3.12[17578:5691946] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# 0: 384x640 (no detections), 68.2ms
# Speed: 2.2ms preprocess, 68.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 closed, 62.1ms
# Speed: 1.0ms preprocess, 62.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 closed, 49.9ms
# Speed: 2.2ms preprocess, 49.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 closed, 52.1ms
# Speed: 1.1ms preprocess, 52.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 closed, 1 opened, 39.1ms
# Speed: 2.5ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 closed, 1 opened, 39.5ms
# ...
